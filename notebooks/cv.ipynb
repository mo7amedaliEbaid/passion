# %% [markdown]
# # Mohamed Ali
#
# ### Job Title: **Flutter Developer**
#
# ### Contact Information
# - **Email**: mo7amedaliebaid@gmail.com
# - **Telephone number**: 01016381636
# - **Address**: Cairo, Egypt
# - **Date of birth**: 16-6-1997
#
# [![Github](https://img.shields.io/badge/github-000000?style=for-the-badge&logo=github&logoColor=#d16c06)](https://github.com/mo7amedaliEbaid) [![LinkedIn](https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/mo7amedebaid/) [![YouTube](https://img.shields.io/badge/YouTube-%23FF0000.svg?style=for-the-badge&logo=YouTube&logoColor=white)](https://www.youtube.com/channel/UCcaLYqe9DJGdqexSQSIgs7w) [![LeetCode](https://img.shields.io/badge/LeetCode-000000?style=for-the-badge&logo=LeetCode&logoColor=#d16c06)](https://leetcode.com/mo7amedaliebaid/)
#
#
# ## Education
#
# ### Bachelor's degree Faculty of Engineering
# - **University**: Kafr ElSheikh University
# - **Final grade**: 7.001/10.000
# - **Date**: May 2016 - August 2021
# - **Graduation project**: *Design of a Car that runs by using Solar Energy and Electrical Energy Controlled by an Android App.*
#
# ## Work Experience
#
# ### WebSTDY
# - **Location**: On Site - Cairo, Egypt
# - **Role**: Flutter Developer
# - **Duration**: April 2024 - Present
#
# ### Sit
# - **Location**: On Site - Cairo, Egypt
# - **Role**: Flutter Developer
# - **Duration**: May 2023 - April 2024
#
# ### United Medical Services Co.
# - **Location**: Hybrid, Alexandria, Egypt
# - **Role**: Flutter Developer
# - **Duration**: December 2022 - September 2023
#
# ### Spark Cloud
# - **Location**: Mansoura, Egypt
# - **Role**: Flutter Developer
# - **Duration**: September 2020 - November 2021
#
# ## Technical Skills
#
# | **Languages/Frameworks** | Flutter, Dart, Javascript, SQL, HTML5, Latex. |
# |--------------------------|------------------------------------------------|
# | **Tools**                | Firebase, Git, Github, Postman, Adobe Xd, Figma, Android Studio, Visual Studio, Agora, Trello, Intellij Idea, Google Cloud, FlutterFlow, Pusher, One Signal. |
# | **Knowledge**            | OOP Concepts, Solid Principles, Design Patterns, Architectural Patterns [MVVM, MVP, MVC]. |
#
# ## Portfolio of Some Relevant Projects
#
# ### Atyab Al Marshoud
# - **Duration**: July 2021 - September 2021
# - **Description**: An e-commerce app for a perfume brand and makeup products that helps people choose and buy perfumes through it, Contains cart, localization, notifications, payment, etc.
# - [Play Store](https://play.google.com/store/apps/details?id=com.line.atyab&pcampaignid=web_share) | [Apple Store](https://apps.apple.com/us/app/atyab-al-marshoud/id1573579912)
#
# ### Al-Qahtani
# - **Duration**: December 2023 - Feb 2024
# - **Description**: Al-Qahtani car rental, It's a flutter app enables customers to rent cars.
# - [Play Store](https://play.google.com/store/apps/details?id=com.sit.qahtani) | [Apple Store](https://apps.apple.com/us/app/%D8%A7%D9%84%D9%82%D8%AD%D8%B7%D8%A7%D9%86%D9%8A/id6473168861)
#
# ### Al-Andalus
# - **Duration**: November 2023 - March 2024
# - **Description**: This application is for Al-Andalus Electrical Appliances Company, It's an E-commerce like app made with flutter for Android and iOS.
# - [Play Store](https://play.google.com/store/apps/details?id=com.sit.andalus&pcampaignid=web_share) | [Apple Store](https://apps.apple.com/us/app/%D8%A7%D9%84%D8%A7%D9%86%D8%AF%D9%84%D8%B3/id6473839184)
#
# ### Noon Cafe
# - **Duration**: January 2024 - February 2024
# - **Description**: Flutter food delivery app, for drinks and food made by noon cafe.
# - [Play Store](https://play.google.com/store/apps/details?id=com.sit.noon&pcampaignid=web_share) | [Apple Store](https://apps.apple.com/us/app/noon-cafe/id6470820374)
#
# ### Dineout Host
# - **Duration**: February 2023 - April 2023
# - **Description**: Dineout Host is the core management app for restauranteurs. If you are looking to make reservations at the trendiest restaurants visit Dineout app for diners.
# - [Play Store](https://play.google.com/store/apps/details?id=com.bsbm.dineout.admin&pcampaignid=web_share) | [Apple Store](https://apps.apple.com/us/app/dineout-host-lite/id1527950208)
#
# ### Alsaif-Express
# - **Duration**: May 2023 - March 2024
# - **Description**: The AlSaif Express application allows you to track your shipments and manage your deliveries in one place. You can locate the nearest service point to deliver or receive packages, and get quotes for shipments as well. GPS location and camera barcode scanning services are also available.
# - [Play Store](https://play.google.com/store/apps/details?id=com.sit.shipping_client)
#
# ### U-Med Customer
# - **Duration**: June 2023 - November 2023
# - **Description**: A Complete flutter medical services app made for united medical services co. this was a freelance project I developed the app from scratch till deploying it to google play store, Firebase and bloc pattern are used in this app. It has many features such as in-app payment, google maps, qr code scanner and more. This is the customer version.
# - [Play Store](https://play.google.com/store/apps/details?id=inzox.umed.customer&pcampaignid=web_share)
#
# ### U-Med Provider
# - **Duration**: June 2023 - November 2023
# - **Description**: This is the admin version of the U-Med app, It's the second app in U-Med medical services. It enables the admin to add new services and control the existing ones.
# - [Play Store](https://play.google.com/store/apps/details?id=inzox.umed.provider&pcampaignid=web_share)
#
# ### Garagek
# - **Duration**: June 2022 - August 2022
# - **Description**: Saudi application allows you to request maintenance of your car with the push of a button. Garagek is an electronic platform specifically designed for the Saudi automotive market. It serves as a link between maintenance workshops and car agencies through Mobile.
# - [Play Store](https://play.google.com/store/apps/details?id=com.webstdy.karagak&pcampaignid=web_share)
#
# ### Dr. Salah El-Sayed
# - **Duration**: December 2023 - March 2024
# - **Description**: By Using this app you can enjoy physical therapy experience with Dr. Salah Al-Sayed, as the app provides a unique experience for users who are looking for effective methods in physical therapy to raise the level of general health and wellness. You can talk to the doctor directly through chat and explain what you are suffering from and your specific health problems.
# - [Play Store](https://play.google.com/store/apps/details?id=com.sit.doctor&pcampaignid=web_share)
#
# ### Color Selector
# - **Duration**: February 2023 - August 2023
# - **Description**: Fully functional color picker working perfectly for web, desktop and mobile.
# - [Github Repo](https://github.com/mo7amedaliEbaid/Color-Selector) | [APK](https://github.com/mo7amedaliEbaid/Color-Selector/releases/tag/v1.0.0) | [Visit Web App](https://todo-firestore-d6bd0.web.app/)
#
# ### Piiicks
# - **Duration**: May 2023 - November 2023
# - **Description**: Flutter e-commerce app, meticulously crafted with clean architecture and powered by the efficient BLoC state management ensuring scalability, maintainability.
# - [Github Repo](https://github.com/mo7amedaliEbaid/piiicks-ecommerce) | [APK](https://github.com/mo7amedaliEbaid/piiicks-ecommerce/releases)
#
# ### Nibbles
# - **Duration**: May 2023 - September 2023
# - **Description**: Flutter-based food app designed to provide users with a delightful and user-friendly experience as they explore a variety of meals and food packages. The app utilizes the Bloc pattern and Cubits for efficient state management, integrates Firebase Firestore for real-time data storage, and incorporates various plugins to enhance its functionality.
# - [Github Repo](https://github.com/mo7amedaliEbaid/nibbles-ecommerce-food) | [APK](https://github.com/mo7amedaliEbaid/nibbles-ecommerce-food/releases)
#
# ### Islamic App
# - **Duration**: September 2022 - December 2022
# - **Description**: A Flutter App with Complete Quran, Prayer time API, Hadith, Azkar and much more. The app is driven by efficient bloc pattern and clean architecture principles.
# - [Github Repo](https://github.com/mo7amedaliEbaid/islamic) | [APK](https://github.com/mo7amedaliEbaid/islamic/releases)
#
# ### Quran App
# - **Duration**: April 2023 - August 2023
# - **Description**: A Flutter App with the complete Holy Quran. It offers translations in multiple languages, audio recitations, and tafsir for understanding Quranic verses better. The app is designed using clean architecture principles and utilizes bloc for efficient state management.
# - [Github Repo](https://github.com/mo7amedaliEbaid/quran) | [APK](https://github.com/mo7amedaliEbaid/quran/releases)
#
# ## Flutter Skills
#
# | **State Management** | Bloc, Provider, Getx, Riverpod. |
# |----------------------|------------------------------|
# | **Networking**       | Http, Dio, Retrofit. |
# | **Database**         | Sqflite, Hive, Get Storage, Drift, Floor, Isar, Objectbox. |
# | **Payment**          | Paymob, HyperPay, Google Pay, Paypal, Stripe. |
# | **Testing Packages** | Flutter-Test, Mochito, Mocktail, Bloc-Test. |
# | **Firebase**         | Firebase Auth, Cloud Firestore, Firebase Storage, Hosting, Cloud Messaging, Cloud Functions, Analytics, Crashlytics, Remote Config, Dynamic Links. |
# | **Common Packages**  | Localization, Local Notifications, Geolocator, Google Maps, Socket Io Client, Google Mobile Ads, Just Audio, Image Picker, Screenutil, Agora Rtc, Video Player, Go Router, Get-It, Build-Runner, Webview, Intl, Pdf, Barcode Scanner, Native Splash, Freezed, Url Launcher, Easy Localization. |
#
#
# ## Languages
#
# - Arabic: Native language.
# - English: Fluent.
