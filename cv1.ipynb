# %%
from IPython.display import display, HTML

html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Mohamed Ali - Flutter Developer</title>
</head>
<body>
    <h1>Mohamed Ali</h1>

    <h3>Job Title: <strong>Flutter Developer</strong></h3>

    <h3>Contact Information</h3>
    <ul>
        <li><strong>Email:</strong> <a href="mailto:mo7amedaliebaid@gmail.com">mo7amedaliebaid@gmail.com</a></li>
        <li><strong>Telephone number:</strong> 01016381636</li>
        <li><strong>Address:</strong> Cairo, Egypt</li>
        <li><strong>Date of birth:</strong> 16-6-1997</li>
    </ul>

    <p>
        <a href="https://github.com/mo7amedaliEbaid">
            <img src="https://img.shields.io/badge/github-000000?style=for-the-badge&logo=github&logoColor=#d16c06" alt="GitHub">
        </a>
        <a href="https://www.linkedin.com/in/mo7amedebaid/">
            <img src="https://img.shields.io/badge/linkedin-%230077B5.svg?style=for-the-badge&logo=linkedin&logoColor=white" alt="LinkedIn">
        </a>
        <a href="https://www.youtube.com/channel/UCcaLYqe9DJGdqexSQSIgs7w">
            <img src="https://img.shields.io/badge/YouTube-%23FF0000.svg?style=for-the-badge&logo=YouTube&logoColor=white" alt="YouTube">
        </a>
        <a href="https://leetcode.com/mo7amedaliebaid/">
            <img src="https://img.shields.io/badge/LeetCode-000000?style=for-the-badge&logo=LeetCode&logoColor=#d16c06" alt="LeetCode">
        </a>
    </p>

    <h2>Education</h2>
    <h3>Bachelor's degree Faculty of Engineering</h3>
    <ul>
        <li><strong>University:</strong> Kafr ElSheikh University</li>
        <li><strong>Final grade:</strong> 7.001/10.000</li>
        <li><strong>Date:</strong> May 2016 - August 2021</li>
        <li><strong>Graduation project:</strong> <em>Design of a Car that runs by using Solar Energy and Electrical Energy Controlled by an Android App.</em></li>
    </ul>

    <h2>Work Experience</h2>

    <h3>WebSTDY</h3>
    <ul>
        <li><strong>Location:</strong> On Site - Cairo, Egypt</li>
        <li><strong>Role:</strong> Flutter Developer</li>
        <li><strong>Duration:</strong> April 2024 - Present</li>
    </ul>

    <h3>Sit</h3>
    <ul>
        <li><strong>Location:</strong> On Site - Cairo, Egypt</li>
        <li><strong>Role:</strong> Flutter Developer</li>
        <li><strong>Duration:</strong> May 2023 - April 2024</li>
    </ul>

    <h3>United Medical Services Co.</h3>
    <ul>
        <li><strong>Location:</strong> Hybrid, Alexandria, Egypt</li>
        <li><strong>Role:</strong> Flutter Developer</li>
        <li><strong>Duration:</strong> December 2022 - September 2023</li>
    </ul>

    <h3>Spark Cloud</h3>
    <ul>
        <li><strong>Location:</strong> Mansoura, Egypt</li>
        <li><strong>Role:</strong> Flutter Developer</li>
        <li><strong>Duration:</strong> September 2020 - November 2021</li>
    </ul>

    <h2>Technical Skills</h2>
    <table>
        <tr>
            <th>Languages/Frameworks</th>
            <td>Flutter, Dart, Javascript, SQL, HTML5, Latex.</td>
        </tr>
        <tr>
            <th>Tools</th>
            <td>Firebase, Git, Github, Postman, Adobe Xd, Figma, Android Studio, Visual Studio, Agora, Trello, Intellij Idea, Google Cloud, FlutterFlow, Pusher, One Signal.</td>
        </tr>
        <tr>
            <th>Knowledge</th>
            <td>OOP Concepts, Solid Principles, Design Patterns, Architectural Patterns [MVVM, MVP, MVC].</td>
        </tr>
    </table>

    <h2>Portfolio of Some Relevant Projects</h2>

    <h3>Atyab Al Marshoud</h3>
    <ul>
        <li><strong>Duration:</strong> July 2021 - September 2021</li>
        <li><strong>Description:</strong> An e-commerce app for a perfume brand and makeup products that helps people choose and buy perfumes through it, Contains cart, localization, notifications, payment, etc.</li>
        <li><a href="https://play.google.com/store/apps/details?id=com.line.atyab&pcampaignid=web_share">Play Store</a> | <a href="https://apps.apple.com/us/app/atyab-al-marshoud/id1573579912">Apple Store</a></li>
    </ul>

    <!-- Repeat similar sections for other projects -->

    <h2>Flutter Skills</h2>
    <table>
        <tr>
            <th>State Management</th>
            <td>Bloc, Provider, Getx, Riverpod.</td>
        </tr>
        <tr>
            <th>Networking</th>
            <td>Http, Dio, Retrofit.</td>
        </tr>
        <tr>
            <th>Database</th>
            <td>Sqflite, Hive, Get Storage, Drift, Floor, Isar, Objectbox.</td>
        </tr>
        <tr>
            <th>Payment</th>
            <td>Paymob, HyperPay, Google Pay, Paypal, Stripe.</td>
        </tr>
        <tr>
            <th>Testing Packages</th>
            <td>Flutter-Test, Mochito, Mocktail, Bloc-Test.</td>
        </tr>
        <tr>
            <th>Firebase</th>
            <td>Firebase Auth, Cloud Firestore, Firebase Storage, Hosting, Cloud Messaging, Cloud Functions, Analytics, Crashlytics, Remote Config, Dynamic Links.</td>
        </tr>
        <tr>
            <th>Common Packages</th>
            <td>Localization, Local Notifications, Geolocator, Google Maps, Socket Io Client, Google Mobile Ads, Just Audio, Image Picker, Screenutil, Agora Rtc, Video Player, Go Router, Get-It, Build-Runner, Webview, Intl, Pdf, Barcode Scanner, Native Splash, Freezed, Url Launcher, Easy Localization.</td>
        </tr>
    </table>

    <h2>Languages</h2>
    <ul>
        <li>Arabic: Native language.</li>
        <li>English: Fluent.</li>
    </ul>
</body>
</html>
"""

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Mohamed Ali - Flutter Developer</title>
# </head>
# <body>
#     <h1>Mohamed Ali</h1>
#
#     <h3>Job Title: <strong>Flutter Developer</strong></h3>
#
#     <h3>Contact Information</h3>
#     <ul>
#         <li><strong>Email:</strong> <a href="mailto:mo7amedaliebaid@gmail.com">mo7amedaliebaid@gmail.com</a></li>
#         <li><strong>Telephone number:</strong> 01016381636</li>
#         <li><strong>Address:</strong> Cairo, Egypt</li>
#         <li><strong>Date of birth:</strong> 16-6-1997</li>
#     </ul>
#
#     <p>
#         <a href="https://github.com/mo7amedaliEbaid">
#             <img src="https://img.shields.io/badge/github-000000?style=for-the-badge&logo=github&logoColor=#d16c06" alt="GitHub">
#         </a>
#         <a href="https://www.linkedin.com/in/mo7amedebaid/">
# ...
